# %%
import time

def traffic_light():
    while True:
        print("Red light: Stop")
        time.sleep(5)  # Red light for 5 seconds
        print("Green light: Go")
        time.sleep(5)  # Green light for 5 seconds
        print("Yellow light: Prepare to stop")
        time.sleep(2)  # Yellow light for 2 seconds

if __name__ == "__main__":
    try:
        traffic_light()
    except KeyboardInterrupt:
        print("Traffic light simulation terminated.")
# Out:
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# Yellow light: Prepare to stop
# Red light: Stop
# Green light: Go
# ...

# %%
length = 11
width = 15 
print(length * width)
print(2*(length + width))

#replace the _ with the updated value. Update the width from 13 to 15
width = 15  
print(length * width)
print(2*(length + width))
# Out:
# 165
# 52
# 165
# 52
