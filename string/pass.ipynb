# %%
import secrets
import string

def generate_password(length):
    characters = string.ascii_letters + string.digits + "@" * string.punctuation.count("@")
    secure_password = ''.join(secrets.choice(characters) for _ in range(length))
    return secure_password

# Example usage to generate a password of length 12
password = generate_password(12)
print(password)

# %%
import pandas as pd
data = pd.read_csv('D:\\progamming\\Practice\\student_scores.csv')

# print(data.head())
# print(data.head())
# print(data.info())
# print(data.describe())
# print(data.shape)
data.dropna()
# data.fillna(value)
# data.drop_duplicates()
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
import pandas as pd
data = pd.read_csv('D:\\progamming\\Practice\\student_scores.csv')
print("\nStudents who scored above 80:")
print(data[data['Scores'] > 80])

# %%
import pandas as pd
data = pd.read_csv('D:\\progamming\\Practice\\student_scores.csv')
print("\nSelecting the 'Hours' column:")
print(data['Hours'])

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('D:\\progamming\\Practice\\student_scores.csv')

plt.title("Distribution of Scores")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
data = pd.read_csv('D:\\progamming\\Practice\\student_scores.csv')
X = data[['Hours']]  # Features
y = data['Scores'] 
model = LinearRegression()
model.fit(X, y)
predicted_scores = model.predict(X)
print("\nPredicted scores using Linear Regression:")
print(predicted_scores)
# Out:
# Predicted scores using Linear Regression:
# [26.92318188 52.3402707  33.76624426 85.57800223 36.69898527 17.14737849
#  92.4210646  56.25059205 83.62284155 28.87834256 77.75735951 60.16091341
#  46.47478866 34.74382459 13.23705714 89.48832358 26.92318188 21.05769985
#  62.11607409 74.8246185  28.87834256 49.40752968 39.63172629 69.9367168
#  78.73493985]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_csv('D:\\progamming\\Practice\\student_scores.csv')
# Bar Plot
plt.figure(figsize=(8, 4))
sns.barplot(x='Hours', y='Scores', data=data)
plt.title('Bar Plot')
plt.show()

# %%
# Line Plot
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_csv('D:\\progamming\\Practice\\student_scores.csv')
plt.figure(figsize=(8, 4))
sns.lineplot(x='Hours', y='Scores', data=data)
plt.title('Line Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Scatter Plot
plt.figure(figsize=(8, 4))
plt.scatter(data['Hours'], data['Scores'])
plt.title('Scatter Plot')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Histogram
plt.figure(figsize=(8, 4))
plt.hist(data['Scores'], bins=5, edgecolor='k')
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Box Plot
plt.figure(figsize=(8, 4))
sns.boxplot(data['Hours'])
plt.title('Box Plot for Hours')
plt.show()

# Violin Plot
plt.figure(figsize=(8, 4))
sns.violinplot(x=data['Scores'], inner='quartile')
plt.title('Violin Plot for Scores')
plt.show()
